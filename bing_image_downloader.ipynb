# %% [markdown]
# <a href="https://colab.research.google.com/github/CoreBeta05/Attendance-Management-System-Using-QR-Code-in-SNSU-AMSQRCODE/blob/main/bing_image_downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
# !mkdir image_data

# %%
from bing_image_downloader import downloader
downloader.download("field cricket damage in corn image", limit=70,  output_dir='image_data')
# Out:
# [%] Downloading Images to /content/image_data/field cricket damage in corn image
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://lgpress.clemson.edu/wp-content/uploads/sites/3/2019/12/fall-armyworms-cause-whorl-damage-on-corn-plants-e1576184709649.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cesaraustralia.com/wp-content/uploads/2020/11/Black-field-cricket-damage-to-sunflower-SARDI-751x500.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.ytimg.com/vi/YOs22IvdAZQ/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://2.bp.blogspot.com/-DhHUt-W14VY/V7ZXDnaahcI/AAAAAAAAAiI/scQ7pn_au9ICgkyy5kSIwB585p5fE4qKQCLcB/s1600/Field%2BCricket.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.plantskydd.ca/wp-content/uploads/2021/03/Deer-damage-corn-field-768x768-1.jpg
# [%] File Downloaded !
#
# ...
